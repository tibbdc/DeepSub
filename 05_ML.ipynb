# %%
import warnings
warnings.filterwarnings("ignore")
from trainer import load_and_preprocess_data
from tool import utils as ul
from tool import config as cfg
import pandas as pd
import pickle
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import numpy as np
# Out:
# 2024-02-26 08:12:55.694820: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-26 08:12:55.694866: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-26 08:12:55.694896: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-26 08:12:55.705079: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-26 08:12:57.608813: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
dataset = load_and_preprocess_data()
X = np.array(dataset.iloc[:, 5:])
y = dataset['label'].values
# Load and preprocess the dataset.
dataset = load_and_preprocess_data()
ground_truth_labels=[]
predicted_labels = []

train_data, vali_data = train_test_split(dataset, test_size=cfg.TRAIN_TEST_SPLIT_SIZE, stratify=dataset['label'], random_state=42)
X_train, y_train = train_data.iloc[:,5:].values, train_data["label"].values
X_val, y_val = vali_data.iloc[:,5:].values, vali_data["label"].values
models_results = {'knn','dt','rf','xg'}
for model_name in models_results:
    predicted_classes, model = ul.run_baseline(X_train, y_train, X_val, y_val, type='multi',method=model_name)
    ground_truth_labels.append(y_val)   
    predicted_labels.append(predicted_classes)
for i in range(len(models_results)):
    report = pd.DataFrame(classification_report(ground_truth_labels[i], predicted_labels[i],output_dict=True)).T
    display(report)
# Out:
# *****DeepSub*****
# *****DeepSub*****
# *****DeepSub*****
# *****DeepSub*****
#               precision    recall  f1-score       support
# 0              0.945516  0.931149  0.938278   4212.000000
# 1              0.959374  0.972225  0.965757  10153.000000
# 2              0.962567  0.917197  0.939335    785.000000
# 3              0.954165  0.943355  0.948729   2295.000000
# 4              0.948148  0.907801  0.927536    141.000000
# 5              0.960033  0.963175  0.961601   1222.000000
# 6              1.000000  0.333333  0.500000      3.000000
# 7              0.931973  0.895425  0.913333    153.000000
# 8              0.953052  0.990244  0.971292    205.000000
# 9              0.977528  0.906250  0.940541     96.000000
# accuracy       0.955671  0.955671  0.955671      0.955671
# macro avg      0.959235  0.876016  0.900640  19265.000000
# weighted avg   0.955625  0.955671  0.955545  19265.000000
#               precision    recall  f1-score       support
# 0              0.982259  0.893875  0.935985   4212.000000
# 1              0.915926  0.994681  0.953681  10153.000000
# 2              0.995627  0.870064  0.928620    785.000000
# 3              0.997080  0.892810  0.942069   2295.000000
# 4              1.000000  0.879433  0.935849    141.000000
# 5              1.000000  0.934534  0.966159   1222.000000
# 6              0.000000  0.000000  0.000000      3.000000
# 7              1.000000  0.758170  0.862454    153.000000
# 8              1.000000  0.975610  0.987654    205.000000
# 9              1.000000  0.864583  0.927374     96.000000
# accuracy       0.947885  0.947885  0.947885      0.947885
# macro avg      0.889089  0.806376  0.843984  19265.000000
# weighted avg   0.951131  0.947885  0.947426  19265.000000
#               precision    recall  f1-score       support
# 0              0.957390  0.933523  0.945306   4212.000000
# 1              0.949995  0.984241  0.966815  10153.000000
# 2              0.984993  0.919745  0.951252    785.000000
# 3              0.980813  0.935512  0.957627   2295.000000
# 4              0.992063  0.886525  0.936330    141.000000
# 5              0.996593  0.957447  0.976628   1222.000000
# 6              0.000000  0.000000  0.000000      3.000000
# 7              1.000000  0.849673  0.918728    153.000000
# 8              1.000000  0.980488  0.990148    205.000000
# 9              1.000000  0.895833  0.945055     96.000000
# accuracy       0.960602  0.960602  0.960602      0.960602
# macro avg      0.886185  0.834299  0.858789  19265.000000
# weighted avg   0.961003  0.960602  0.960390  19265.000000
#               precision    recall  f1-score       support
# 0              0.857279  0.851377  0.854318   4212.000000
# 1              0.917262  0.910667  0.913952  10153.000000
# 2              0.811808  0.840764  0.826033    785.000000
# 3              0.849374  0.857516  0.853426   2295.000000
# 4              0.862595  0.801418  0.830882    141.000000
# 5              0.865873  0.892799  0.879130   1222.000000
# 6              0.000000  0.000000  0.000000      3.000000
# 7              0.558140  0.627451  0.590769    153.000000
# 8              0.783550  0.882927  0.830275    205.000000
# 9              0.828947  0.656250  0.732558     96.000000
# accuracy       0.882637  0.882637  0.882637      0.882637
# macro avg      0.733483  0.732117  0.731134  19265.000000
# weighted avg   0.883246  0.882637  0.882801  19265.000000

# %%
results_dict = {'model': models_results, 'ground_truth': ground_truth_labels, 'predicted': predicted_labels}
# Convert the dictionary to a Pandas DataFrame
results_df = pd.DataFrame([results_dict])
# Save the DataFrame to a CSV file
results_df.to_csv('output/ml_results.csv', index=False)

# %%
dataset = load_and_preprocess_data()
X = np.array(dataset.iloc[:, 5:])
y = dataset['label'].values

# Define the K-fold cross-validator
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

fold_no = 1

fold_metrics = {
    'Accuracy': [],
    'Precision': [],
    'Recall': [],
    'F1 Score': [],
    }


results_df = pd.DataFrame(columns=['Model', 'Fold', 'Accuracy', 'Precision', 'Recall', 'F1_Score'])
res = []

best_f1_score = 0
best_model_name = None
best_predicted_classes = None

for train, test in kfold.split(X, y):

    print(f'Training for fold {fold_no} ...')

    # Split data into training and validation sets
    X_train, X_val = X[train], X[test]
    y_train, y_val = y[train], y[test]
    
    print(f'X_train: {X_train.shape}')
    print(f'X_val: {X_val.shape}')
    for model_name in models_results:
        
        predicted_classes, model = ul.run_baseline(X_train, y_train, X_val, y_val, type='multi',method=model_name)
        
        # Save metrics
        print(f'predicted_classes: {predicted_classes}')
        accuracy  = accuracy_score(y_val, predicted_classes)
        precision = precision_score(y_val, predicted_classes, average='macro', zero_division=0)
        recall    = recall_score(y_val, predicted_classes, average='macro', zero_division=0)
        f1        = f1_score(y_val, predicted_classes, average='macro', zero_division=0)

        # Save metrics to dataframe
        res.append({
            'Model': model_name,
            'Fold': fold_no,
            'Accuracy': accuracy,
            'Precision': precision,
            'Recall': recall,
            'F1 Score': f1
        })
        
        if f1 > best_f1_score:
            best_f1_score = f1
            # Save the best model using pickle
            with open(f'model/ml_{model_name}.pkl', 'wb') as model_file:
                pickle.dump(model, model_file)
    
    # Increment fold number
    fold_no += 1  
    
results_df = pd.DataFrame(res)
results_df.to_csv('output/cross_validation_results_ml.csv', index=False)
display(results_df)
# Out:
# Training for fold 1 ...
# X_train: (86691, 1280)
# X_val: (9633, 1280)
# *****DeepSub*****
# predicted_classes: [0 1 1 ... 1 1 1]
# *****DeepSub*****
# predicted_classes: [1 1 1 ... 1 1 1]
# *****DeepSub*****
# predicted_classes: [3 1 1 ... 1 1 1]
# *****DeepSub*****
# predicted_classes: [0 1 0 ... 1 1 3]
# Training for fold 2 ...
# X_train: (86691, 1280)
# X_val: (9633, 1280)
# *****DeepSub*****
# predicted_classes: [1 1 1 ... 1 1 1]
# *****DeepSub*****
# predicted_classes: [1 1 1 ... 1 1 1]
# *****DeepSub*****
# predicted_classes: [1 1 1 ... 1 1 1]
# *****DeepSub*****
# predicted_classes: [1 1 1 ... 1 1 1]
# Training for fold 3 ...
# X_train: (86691, 1280)
# X_val: (9633, 1280)
# *****DeepSub*****
# predicted_classes: [0 3 1 ... 1 1 1]
# *****DeepSub*****
# predicted_classes: [0 1 1 ... 1 1 1]
# *****DeepSub*****
# predicted_classes: [0 1 1 ... 1 1 1]
# *****DeepSub*****
# predicted_classes: [1 0 1 ... 1 3 1]
# Training for fold 4 ...
# X_train: (86691, 1280)
# X_val: (9633, 1280)
# *****DeepSub*****
# predicted_classes: [1 1 1 ... 1 1 1]
# *****DeepSub*****
# predicted_classes: [1 1 1 ... 0 1 1]
# *****DeepSub*****
# predicted_classes: [1 1 1 ... 0 1 1]
# *****DeepSub*****
# predicted_classes: [1 1 1 ... 0 1 0]
# Training for fold 5 ...
# X_train: (86692, 1280)
# X_val: (9632, 1280)
# *****DeepSub*****
# predicted_classes: [9 1 1 ... 1 5 1]
# *****DeepSub*****
# predicted_classes: [9 1 1 ... 1 1 1]
# *****DeepSub*****
# predicted_classes: [9 1 1 ... 1 5 1]
# *****DeepSub*****
# predicted_classes: [9 3 1 ... 1 5 1]
# Training for fold 6 ...
# X_train: (86692, 1280)
# X_val: (9632, 1280)
# *****DeepSub*****
# predicted_classes: [9 0 1 ... 1 1 6]
# *****DeepSub*****
# predicted_classes: [9 0 1 ... 1 1 1]
# *****DeepSub*****
# predicted_classes: [9 0 1 ... 1 1 1]
# *****DeepSub*****
# predicted_classes: [9 0 1 ... 1 3 1]
# Training for fold 7 ...
# X_train: (86692, 1280)
# X_val: (9632, 1280)
# *****DeepSub*****
# predicted_classes: [9 9 9 ... 1 1 1]
# *****DeepSub*****
# predicted_classes: [9 9 9 ... 1 1 1]
# *****DeepSub*****
# predicted_classes: [9 9 9 ... 1 1 1]
# *****DeepSub*****
# predicted_classes: [9 9 9 ... 1 1 1]
# Training for fold 8 ...
# X_train: (86692, 1280)
# X_val: (9632, 1280)
# *****DeepSub*****
# predicted_classes: [9 1 1 ... 1 1 1]
# *****DeepSub*****
# predicted_classes: [9 1 1 ... 1 1 1]
# *****DeepSub*****
# predicted_classes: [9 1 1 ... 1 1 1]
# *****DeepSub*****
# predicted_classes: [9 1 1 ... 3 1 1]
# Training for fold 9 ...
# X_train: (86692, 1280)
# X_val: (9632, 1280)
# *****DeepSub*****
# predicted_classes: [1 1 9 ... 1 3 1]
# *****DeepSub*****
# predicted_classes: [1 1 9 ... 1 1 1]
# *****DeepSub*****
# predicted_classes: [1 1 9 ... 1 1 1]
# *****DeepSub*****
# predicted_classes: [0 1 9 ... 1 3 1]
# Training for fold 10 ...
# X_train: (86692, 1280)
# X_val: (9632, 1280)
# *****DeepSub*****
# predicted_classes: [1 1 1 ... 1 1 1]
# *****DeepSub*****
# predicted_classes: [1 1 1 ... 1 1 1]
# *****DeepSub*****
# predicted_classes: [1 1 1 ... 1 1 1]
# *****DeepSub*****
# predicted_classes: [1 1 1 ... 1 0 3]
#    Model  Fold  Accuracy  Precision    Recall  F1 Score
# 0    knn     1  0.959929   0.875584  0.849769  0.862288
# 1     rf     1  0.947265   0.886866  0.812262  0.846779
# 2     xg     1  0.958891   0.886691  0.835250  0.859661
# 3     dt     1  0.883006   0.738906  0.750279  0.743978
# 4    knn     2  0.958891   0.966984  0.891242  0.920372
# 5     rf     2  0.950898   0.888932  0.800344  0.840113
# 6     xg     2  0.960448   0.886341  0.831049  0.857057
# 7     dt     2  0.890584   0.752978  0.729458  0.739283
# 8    knn     3  0.958995   0.864903  0.854649  0.859518
# 9     rf     3  0.950690   0.889864  0.805174  0.843823
# 10    xg     3  0.961590   0.985554  0.891077  0.928964
# 11    dt     3  0.893284   0.761873  0.753354  0.756665
# 12   knn     4  0.959514   0.869492  0.841844  0.855082
# 13    rf     4  0.948510   0.887882  0.792554  0.834642
# 14    xg     4  0.961383   0.881366  0.822822  0.850204
# 15    dt     4  0.892557   0.771590  0.747379  0.758493
# 16   knn     5  0.956188   0.958420  0.938918  0.948156
# 17    rf     5  0.949128   0.889647  0.799699  0.840549
# 18    xg     5  0.959925   0.882462  0.829041  0.853986
# 19    dt     5  0.885174   0.753603  0.744948  0.748581
# 20   knn     6  0.959406   0.965222  0.947946  0.956104
# 21    rf     6  0.948609   0.889054  0.812028  0.847223
# 22    xg     6  0.958783   0.884676  0.837618  0.859751
# 23    dt     6  0.884863   0.748335  0.753498  0.750491
# 24   knn     7  0.958264   0.863035  0.846939  0.854429
# 25    rf     7  0.951931   0.889406  0.815245  0.849490
# 26    xg     7  0.960029   0.886453  0.834370  0.858989
# 27    dt     7  0.890262   0.754223  0.749863  0.751663
# 28   knn     8  0.956914   0.867794  0.839786  0.853121
# 29    rf     8  0.946013   0.885958  0.804321  0.841000
# 30    xg     8  0.956084   0.883420  0.833596  0.857083
# 31    dt     8  0.887043   0.736701  0.742274  0.739384
# 32   knn     9  0.959510   0.963047  0.950775  0.956746
# 33    rf     9  0.950789   0.889532  0.815846  0.849805
# 34    xg     9  0.962625   0.885107  0.841100  0.862139
# 35    dt     9  0.884240   0.732538  0.750637  0.741154
# 36   knn    10  0.957018   0.858443  0.851064  0.854590
# 37    rf    10  0.951620   0.889610  0.815527  0.849518
# 38    xg    10  0.962728   0.886165  0.836754  0.859948
# 39    dt    10  0.885797   0.755105  0.752630  0.753684
