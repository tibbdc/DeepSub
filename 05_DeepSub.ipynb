# %%
# ! python featurizer.py

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from tool import model as md
from tool import config as cfg
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

def load_and_preprocess_data():
    """
    Load and preprocess the dataset.

    Args:
        None.

    Returns:
        pd.DataFrame: Preprocessed dataset containing the following columns:
            - 'uniprot_id': UniProt ID.
            - 'seq': Sequence.
            - 'f1': Feature value.
            - 'new_label': Encoded label value using LabelEncoder.
            - 'label': Original label value.
    """
    dataset = pd.read_csv(cfg.DATA_PATH)
    feature = pd.read_feather(f'{cfg.FEATURE_PATH}feature_esm2.feather')
    dataset = dataset.rename(columns={'Entry': 'uniprot_id', 'Sequence': 'seq'})
    data_df = dataset.merge(feature, on='uniprot_id', how='left')
    data_df = data_df[~data_df.f1.isnull()]
    data_df['label'] = LabelEncoder().fit_transform(data_df['label'])

    return data_df

def reshape_features(data):
    """
    Reshape input data to have 3 dimensions.

    Args:
        data (np.ndarray): Input data to be reshaped.

    Returns:
        np.ndarray: Reshaped data with shape (n_samples, 1, n_features).
    """
    return np.array(data).reshape(data.shape[0],1,-1)
# Out:
# 2024-02-22 03:01:17.478879: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-22 03:01:17.478922: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-22 03:01:17.478957: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-22 03:01:17.491311: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-22 03:01:19.209589: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Load and preprocess the dataset.
dataset = load_and_preprocess_data()

# Create a Pandas Excel writer
excel_writer = pd.ExcelWriter('output/cv_labels.xlsx', engine='xlsxwriter')
best_val_accuracy = 0.0
best_model_path = ''
folder_path = "model/"

# StratifiedKFold
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

for fold, (train_index, val_index) in enumerate(skf.split(dataset.iloc[:, 3:], dataset['label'])):
    print(f"\nFold {fold + 1}:")

    train_data, vali_data = dataset.iloc[train_index], dataset.iloc[val_index]

    X_train = reshape_features(train_data.iloc[:, 3:])
    X_val = reshape_features(vali_data.iloc[:, 3:])

    print(f'X_train shape: {X_train.shape}')
    print(f'X_val shape: {X_val.shape}')

    gru_attention_model = md.GRUWithAttentionModel(input_shape=cfg.INPUT_SHAPE, num_classes=cfg.NUM_CLASSES)
    gru_attention_model.compile_model()

    history = gru_attention_model.train(
        X_train,
        train_data['label'],
        X_val,
        vali_data['label'],
        batch_size=cfg.BATCH_SIZE,
        epochs=cfg.EPOCHS
    )

    # Track and save only the best model
    if history.history['val_accuracy'][-1] > best_val_accuracy:
        best_val_accuracy = history.history['val_accuracy'][-1]
        gru_attention_model.save_model(f'{folder_path}deepsub_new.h5')

    # eval
    val_predictions = gru_attention_model.model.predict(X_val, batch_size=cfg.BATCH_SIZE)
    ground_truth_labels = vali_data['label'].values
    predicted_labels = np.argmax(val_predictions, axis=1)

    # Export data to different sheets
    export_data = pd.DataFrame({'GroundTruth': ground_truth_labels, 'PredictedLabels': predicted_labels})
    sheet_name = f'fold{fold}'
    export_data.to_excel(excel_writer, sheet_name=sheet_name, index=False)
excel_writer.close()
print("\nTrain Over")
# Out:
# Fold 1:
# X_train shape: (86644, 1, 1280)
# X_val shape: (9628, 1, 1280)
# 2024-02-22 03:01:45.314082: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31277 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:73:00.0, compute capability: 8.6
# 2024-02-22 03:01:46.064580: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# Epoch 1/200
# 2024-02-22 03:01:57.777702: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8700
# 2024-02-22 03:01:58.198902: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f591c00abc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-02-22 03:01:58.198959: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2024-02-22 03:01:58.213799: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-02-22 03:01:58.436892: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 43/43 [==============================] - 12s 52ms/step - loss: 1.3255 - accuracy: 0.5560 - val_loss: 1.0160 - val_accuracy: 0.6506
# Epoch 2/200
# 43/43 [==============================] - 1s 24ms/step - loss: 0.8494 - accuracy: 0.7222 - val_loss: 0.6523 - val_accuracy: 0.8056
# Epoch 3/200
# 43/43 [==============================] - 1s 21ms/step - loss: 0.5978 - accuracy: 0.8216 - val_loss: 0.4749 - val_accuracy: 0.8646
# Epoch 4/200
# 43/43 [==============================] - 1s 34ms/step - loss: 0.4880 - accuracy: 0.8568 - val_loss: 0.3922 - val_accuracy: 0.8883
# Epoch 5/200
# 43/43 [==============================] - 2s 55ms/step - loss: 0.4359 - accuracy: 0.8718 - val_loss: 0.3480 - val_accuracy: 0.9009
# Epoch 6/200
# 43/43 [==============================] - 1s 34ms/step - loss: 0.4053 - accuracy: 0.8793 - val_loss: 0.3212 - val_accuracy: 0.9077
# Epoch 7/200
# 43/43 [==============================] - 2s 51ms/step - loss: 0.3869 - accuracy: 0.8838 - val_loss: 0.3044 - val_accuracy: 0.9119
# Epoch 8/200
# 43/43 [==============================] - 2s 47ms/step - loss: 0.3692 - accuracy: 0.8891 - val_loss: 0.2984 - val_accuracy: 0.9132
# Epoch 9/200
# 43/43 [==============================] - 2s 53ms/step - loss: 0.3594 - accuracy: 0.8916 - val_loss: 0.2809 - val_accuracy: 0.9181
# Epoch 10/200
# 43/43 [==============================] - 2s 58ms/step - loss: 0.3467 - accuracy: 0.8939 - val_loss: 0.2622 - val_accuracy: 0.9267
# Epoch 11/200
# 43/43 [==============================] - 2s 54ms/step - loss: 0.3361 - accuracy: 0.8960 - val_loss: 0.2567 - val_accuracy: 0.9258
# Epoch 12/200
# 43/43 [==============================] - 1s 34ms/step - loss: 0.3260 - accuracy: 0.8986 - val_loss: 0.2467 - val_accuracy: 0.9292
# Epoch 13/200
# 43/43 [==============================] - 1s 32ms/step - loss: 0.3201 - accuracy: 0.9013 - val_loss: 0.2426 - val_accuracy: 0.9280
# Epoch 14/200
# 43/43 [==============================] - 2s 35ms/step - loss: 0.3090 - accuracy: 0.9054 - val_loss: 0.2340 - val_accuracy: 0.9306
# Epoch 15/200
# 43/43 [==============================] - 2s 36ms/step - loss: 0.3018 - accuracy: 0.9070 - val_loss: 0.2312 - val_accuracy: 0.9287
# Epoch 16/200
# 43/43 [==============================] - 2s 36ms/step - loss: 0.2940 - accuracy: 0.9101 - val_loss: 0.2264 - val_accuracy: 0.9311
# Epoch 17/200
# 43/43 [==============================] - 2s 41ms/step - loss: 0.2845 - accuracy: 0.9126 - val_loss: 0.2157 - val_accuracy: 0.9353
# Epoch 18/200
# 43/43 [==============================] - 1s 30ms/step - loss: 0.2759 - accuracy: 0.9148 - val_loss: 0.2148 - val_accuracy: 0.9338
# Epoch 19/200
# 43/43 [==============================] - 1s 29ms/step - loss: 0.2698 - accuracy: 0.9170 - val_loss: 0.2075 - val_accuracy: 0.9374
# Epoch 20/200
# 43/43 [==============================] - 1s 34ms/step - loss: 0.2607 - accuracy: 0.9194 - val_loss: 0.2025 - val_accuracy: 0.9387
# Epoch 21/200
# 43/43 [==============================] - 1s 31ms/step - loss: 0.2554 - accuracy: 0.9211 - val_loss: 0.1986 - val_accuracy: 0.9394
# Epoch 22/200
# 43/43 [==============================] - 1s 26ms/step - loss: 0.2477 - accuracy: 0.9242 - val_loss: 0.1920 - val_accuracy: 0.9419
# Epoch 23/200
# 43/43 [==============================] - 1s 26ms/step - loss: 0.2368 - accuracy: 0.9279 - val_loss: 0.1872 - val_accuracy: 0.9434
# Epoch 24/200
# 43/43 [==============================] - 2s 36ms/step - loss: 0.2363 - accuracy: 0.9281 - val_loss: 0.1850 - val_accuracy: 0.9429
# Epoch 25/200
# 43/43 [==============================] - 1s 29ms/step - loss: 0.2286 - accuracy: 0.9304 - val_loss: 0.1860 - val_accuracy: 0.9417
# Epoch 26/200
# 43/43 [==============================] - 1s 32ms/step - loss: 0.2228 - accuracy: 0.9317 - val_loss: 0.1769 - val_accuracy: 0.9436
# Epoch 27/200
# 43/43 [==============================] - 3s 64ms/step - loss: 0.2189 - accuracy: 0.9334 - val_loss: 0.1753 - val_accuracy: 0.9454
# Epoch 28/200
# 43/43 [==============================] - 3s 60ms/step - loss: 0.2123 - accuracy: 0.9355 - val_loss: 0.1737 - val_accuracy: 0.9452
# Epoch 29/200
# 43/43 [==============================] - 2s 53ms/step - loss: 0.2052 - accuracy: 0.9374 - val_loss: 0.1691 - val_accuracy: 0.9469
# Epoch 30/200
# 43/43 [==============================] - 1s 24ms/step - loss: 0.2014 - accuracy: 0.9387 - val_loss: 0.1659 - val_accuracy: 0.9482
# Epoch 31/200
# 43/43 [==============================] - 1s 20ms/step - loss: 0.1963 - accuracy: 0.9392 - val_loss: 0.1637 - val_accuracy: 0.9472
# Epoch 32/200
# 43/43 [==============================] - 1s 26ms/step - loss: 0.1901 - accuracy: 0.9420 - val_loss: 0.1608 - val_accuracy: 0.9494
# Epoch 33/200
# 43/43 [==============================] - 1s 24ms/step - loss: 0.1868 - accuracy: 0.9429 - val_loss: 0.1595 - val_accuracy: 0.9482
# Epoch 34/200
# 43/43 [==============================] - 1s 23ms/step - loss: 0.1842 - accuracy: 0.9432 - val_loss: 0.1545 - val_accuracy: 0.9510
# Epoch 35/200
# 43/43 [==============================] - 1s 28ms/step - loss: 0.1796 - accuracy: 0.9452 - val_loss: 0.1524 - val_accuracy: 0.9515
# Epoch 36/200
# 43/43 [==============================] - 1s 29ms/step - loss: 0.1757 - accuracy: 0.9469 - val_loss: 0.1540 - val_accuracy: 0.9509
# Epoch 37/200
# 43/43 [==============================] - 1s 24ms/step - loss: 0.1716 - accuracy: 0.9472 - val_loss: 0.1508 - val_accuracy: 0.9518
# Epoch 38/200
# 43/43 [==============================] - 1s 23ms/step - loss: 0.1677 - accuracy: 0.9487 - val_loss: 0.1481 - val_accuracy: 0.9524
# Epoch 39/200
# 43/43 [==============================] - 1s 22ms/step - loss: 0.1639 - accuracy: 0.9499 - val_loss: 0.1471 - val_accuracy: 0.9514
# Epoch 40/200
# 43/43 [==============================] - 1s 26ms/step - loss: 0.1624 - accuracy: 0.9497 - val_loss: 0.1432 - val_accuracy: 0.9527
# Epoch 41/200
# 43/43 [==============================] - 1s 26ms/step - loss: 0.1608 - accuracy: 0.9507 - val_loss: 0.1433 - val_accuracy: 0.9544
# Epoch 42/200
# 43/43 [==============================] - 1s 25ms/step - loss: 0.1578 - accuracy: 0.9513 - val_loss: 0.1432 - val_accuracy: 0.9536
# Epoch 43/200
# 43/43 [==============================] - 1s 31ms/step - loss: 0.1553 - accuracy: 0.9517 - val_loss: 0.1433 - val_accuracy: 0.9539
# Epoch 44/200
# 43/43 [==============================] - 1s 26ms/step - loss: 0.1519 - accuracy: 0.9536 - val_loss: 0.1384 - val_accuracy: 0.9546
# Epoch 45/200
# 43/43 [==============================] - 1s 24ms/step - loss: 0.1485 - accuracy: 0.9541 - val_loss: 0.1383 - val_accuracy: 0.9554
# Epoch 46/200
# 43/43 [==============================] - 1s 22ms/step - loss: 0.1451 - accuracy: 0.9552 - val_loss: 0.1363 - val_accuracy: 0.9555
# Epoch 47/200
# 43/43 [==============================] - 1s 22ms/step - loss: 0.1449 - accuracy: 0.9545 - val_loss: 0.1341 - val_accuracy: 0.9566
# Epoch 48/200
# 43/43 [==============================] - 1s 22ms/step - loss: 0.1418 - accuracy: 0.9555 - val_loss: 0.1358 - val_accuracy: 0.9551
# Epoch 49/200
# 43/43 [==============================] - 1s 21ms/step - loss: 0.1391 - accuracy: 0.9565 - val_loss: 0.1368 - val_accuracy: 0.9549
# Epoch 50/200
# 43/43 [==============================] - 1s 22ms/step - loss: 0.1373 - accuracy: 0.9571 - val_loss: 0.1326 - val_accuracy: 0.9561
# Epoch 51/200
# 43/43 [==============================] - 1s 27ms/step - loss: 0.1357 - accuracy: 0.9575 - val_loss: 0.1313 - val_accuracy: 0.9566
# Epoch 52/200
# 43/43 [==============================] - 1s 24ms/step - loss: 0.1341 - accuracy: 0.9583 - val_loss: 0.1309 - val_accuracy: 0.9565
# Epoch 53/200
# 43/43 [==============================] - 1s 19ms/step - loss: 0.1316 - accuracy: 0.9588 - val_loss: 0.1311 - val_accuracy: 0.9573
# Epoch 54/200
# 43/43 [==============================] - 1s 19ms/step - loss: 0.1310 - accuracy: 0.9592 - val_loss: 0.1290 - val_accuracy: 0.9578
# Epoch 55/200
# 43/43 [==============================] - 1s 19ms/step - loss: 0.1272 - accuracy: 0.9598 - val_loss: 0.1277 - val_accuracy: 0.9587
# Epoch 56/200
# 43/43 [==============================] - 1s 21ms/step - loss: 0.1275 - accuracy: 0.9600 - val_loss: 0.1270 - val_accuracy: 0.9584
# Epoch 57/200
# 43/43 [==============================] - 1s 21ms/step - loss: 0.1246 - accuracy: 0.9605 - val_loss: 0.1293 - val_accuracy: 0.9579
# Epoch 58/200
# 43/43 [==============================] - 1s 19ms/step - loss: 0.1238 - accuracy: 0.9606 - val_loss: 0.1295 - val_accuracy: 0.9573
# Epoch 59/200
# 43/43 [==============================] - 1s 20ms/step - loss: 0.1219 - accuracy: 0.9619 - val_loss: 0.1264 - val_accuracy: 0.9587
# Epoch 60/200
# 43/43 [==============================] - 1s 23ms/step - loss: 0.1203 - accuracy: 0.9618 - val_loss: 0.1249 - val_accuracy: 0.9591
# Epoch 61/200
# 43/43 [==============================] - 1s 23ms/step - loss: 0.1191 - accuracy: 0.9625 - val_loss: 0.1241 - val_accuracy: 0.9581
# Epoch 62/200
# 43/43 [==============================] - 1s 25ms/step - loss: 0.1175 - accuracy: 0.9622 - val_loss: 0.1229 - val_accuracy: 0.9600
# Epoch 63/200
# 43/43 [==============================] - 1s 22ms/step - loss: 0.1156 - accuracy: 0.9633 - val_loss: 0.1239 - val_accuracy: 0.9596
# Epoch 64/200
# 43/43 [==============================] - 1s 25ms/step - loss: 0.1128 - accuracy: 0.9638 - val_loss: 0.1217 - val_accuracy: 0.9599
# Epoch 65/200
# 43/43 [==============================] - 1s 23ms/step - loss: 0.1145 - accuracy: 0.9629 - val_loss: 0.1203 - val_accuracy: 0.9596
# Epoch 66/200
# 43/43 [==============================] - 1s 24ms/step - loss: 0.1124 - accuracy: 0.9641 - val_loss: 0.1236 - val_accuracy: 0.9597
# Epoch 67/200
# 43/43 [==============================] - 1s 25ms/step - loss: 0.1099 - accuracy: 0.9651 - val_loss: 0.1205 - val_accuracy: 0.9604
# Epoch 68/200
# 43/43 [==============================] - 1s 23ms/step - loss: 0.1101 - accuracy: 0.9644 - val_loss: 0.1210 - val_accuracy: 0.9601
# Epoch 69/200
# 43/43 [==============================] - 1s 20ms/step - loss: 0.1071 - accuracy: 0.9655 - val_loss: 0.1218 - val_accuracy: 0.9600
# Epoch 70/200
# 43/43 [==============================] - 1s 19ms/step - loss: 0.1059 - accuracy: 0.9660 - val_loss: 0.1229 - val_accuracy: 0.9597
# Epoch 71/200
# 43/43 [==============================] - 1s 21ms/step - loss: 0.1068 - accuracy: 0.9660 - val_loss: 0.1237 - val_accuracy: 0.9599
# Epoch 72/200
# 43/43 [==============================] - 1s 21ms/step - loss: 0.1046 - accuracy: 0.9665 - val_loss: 0.1192 - val_accuracy: 0.9607
# Epoch 73/200
# 43/43 [==============================] - 1s 21ms/step - loss: 0.1035 - accuracy: 0.9664 - val_loss: 0.1187 - val_accuracy: 0.9605
# Epoch 74/200
# 43/43 [==============================] - 1s 20ms/step - loss: 0.1024 - accuracy: 0.9670 - val_loss: 0.1225 - val_accuracy: 0.9607
# Epoch 75/200
# 43/43 [==============================] - 1s 20ms/step - loss: 0.1017 - accuracy: 0.9671 - val_loss: 0.1183 - val_accuracy: 0.9612
# Epoch 76/200
# 43/43 [==============================] - 1s 19ms/step - loss: 0.1020 - accuracy: 0.9665 - val_loss: 0.1168 - val_accuracy: 0.9613
# Epoch 77/200
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0985 - accuracy: 0.9677 - val_loss: 0.1173 - val_accuracy: 0.9614
# Epoch 78/200
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0972 - accuracy: 0.9677 - val_loss: 0.1162 - val_accuracy: 0.9615
# Epoch 79/200
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0970 - accuracy: 0.9684 - val_loss: 0.1199 - val_accuracy: 0.9608
# Epoch 80/200
# 41/43 [===========================>..] - ETA: 0s - loss: 0.0968 - accuracy: 0.9681

# %%
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score, recall_score
import numpy as np
from sklearn.metrics import classification_report
accuracies, f1_scores, recalls = [], [], []
all_ground_truth_labels = []
all_predicted_labels = []

for fold in range(10):
    print(f"\nFold {fold + 1}:")

    # 读取每个折叠的真实标签和预测标签
    fold_data = pd.read_excel('output/cv_labels.xlsx', sheet_name=f'fold{fold}')

    ground_truth_labels = fold_data['GroundTruth'].values
    predicted_labels = fold_data['PredictedLabels'].values
    # 将当前折叠的标签添加到列表中
    all_ground_truth_labels.append(ground_truth_labels)
    all_predicted_labels.append(predicted_labels)
    
    # 计算每个折叠的准确率、F1 分数和召回率
    accuracy = accuracy_score(ground_truth_labels, predicted_labels)
    f1 = f1_score(ground_truth_labels, predicted_labels, average='weighted')
    recall = recall_score(ground_truth_labels, predicted_labels, average='weighted')

    accuracies.append(accuracy)
    f1_scores.append(f1)
    recalls.append(recall)

    print(f'Accuracy: {accuracy:.4f}')
    print(f'F1 Score: {f1:.4f}')
    print(f'Recall: {recall:.4f}')

# 计算交叉验证的平均准确率、F1 分数和召回率
avg_accuracy = np.mean(accuracies)
avg_f1 = np.mean(f1_scores)
avg_recall = np.mean(recalls)

print(f'Average Accuracy Across Folds: {avg_accuracy:.4f}')
print(f'Average F1 Score Across Folds: {avg_f1:.4f}')
print(f'Average Recall Across Folds: {avg_recall:.4f}')
# Out:
# Fold 1:
# Accuracy: 0.9778
# F1 Score: 0.9777
# Recall: 0.9778
#
# Fold 2:
# Accuracy: 0.9758
# F1 Score: 0.9757
# Recall: 0.9758
#
# Fold 3:
# Accuracy: 0.9759
# F1 Score: 0.9758
# Recall: 0.9759
#
# Fold 4:
# Accuracy: 0.9758
# F1 Score: 0.9758
# Recall: 0.9758
#
# Fold 5:
# Accuracy: 0.9758
# F1 Score: 0.9757
# Recall: 0.9758
#
# Fold 6:
# Accuracy: 0.9744
# F1 Score: 0.9744
# Recall: 0.9744
#
# Fold 7:
# Accuracy: 0.9743
# F1 Score: 0.9742
# Recall: 0.9743
#
# Fold 8:
# Accuracy: 0.9756
# F1 Score: 0.9755
# Recall: 0.9756
#
# Fold 9:
# Accuracy: 0.9746
# F1 Score: 0.9746
# Recall: 0.9746
#
# Fold 10:
# Accuracy: 0.9769
# F1 Score: 0.9768
# Recall: 0.9769
# Average Accuracy Across Folds: 0.9757
# Average F1 Score Across Folds: 0.9756
# Average Recall Across Folds: 0.9757

# %%
# 合并所有折叠的标签
all_ground_truth_labels = np.concatenate(all_ground_truth_labels)
all_predicted_labels = np.concatenate(all_predicted_labels)

# %%
print("\nOverall Classification Report:")
report = pd.DataFrame(classification_report(all_ground_truth_labels, all_predicted_labels,output_dict=True)).T
report
# Out:
# Overall Classification Report:
#               precision    recall  f1-score        support
# 0              0.973111  0.961220  0.967129   25451.000000
# 1              0.974282  0.986222  0.980215   60384.000000
# 2              0.983095  0.962372  0.972623    5076.000000
# 3              0.975273  0.965651  0.970438   13887.000000
# 4              0.985384  0.967703  0.976463     836.000000
# 5              0.987909  0.973271  0.980536    6884.000000
# 6              0.892857  0.714286  0.793651      35.000000
# 7              0.977925  0.940552  0.958874     942.000000
# 8              0.998108  0.986904  0.992474    1069.000000
# 9              0.981516  0.958484  0.969863     554.000000
# accuracy       0.975668  0.975668  0.975668       0.975668
# macro avg      0.972946  0.941666  0.956227  115118.000000
# weighted avg   0.975688  0.975668  0.975632  115118.000000
